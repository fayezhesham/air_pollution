# %%
import pandas as pd

# %%
df = pd.read_csv("data_temp.csv")

# %%
df["Year"] = df["Year"] + 4

# %%
import plotly.express as px
fig = px.line(data_frame = df[:600], x = "Year", y = "Air pollution (total) (deaths per 100,000)", color = "Entity", template = "plotly_dark")
fig.show()

# %%
len(df["Entity"].unique())
# Out:
# 231
